# %%
# %matplotlib inline
producer = 'saturation';
in_fname = 'ly_029000_xyz_0205_0005_5005.root';

# %%
# for processing
import sys
from ROOT import TChain, larutil
from larlite import larlite as fmwk

# for plotting
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mpc
import matplotlib.dates as dts

import matplotlib.patches as patches

import numpy as np
import os
plt.rcParams.update({'font.size': 16})

if not len(sys.argv) == 3:
    print 'Usage: %s OpDetWaveformProducer InputFile'
    sys.exit(1)

#producer = sys.argv[1]
#in_fname = sys.argv[2]

print
print 'Input info ... producer =',producer,' : file =',in_fname
print

my_module = fmwk.OpHitFinder()
my_module.Configure("ophitfindermodule.fcl")
my_module.initialize()

ch=TChain("opdigit_%s_tree" % producer)
ch.AddFile(in_fname)

my_module2 = fmwk.OpHitFinder()
my_module2.Configure("ophitfindermodule2.fcl")
my_module2.initialize()

ch=TChain("opdigit_%s_tree" % producer)
ch.AddFile(in_fname)
# Out:
# Input info ... producer = saturation  : file = ly_029000_xyz_0205_0005_5005.root
# 1

# %%
if ch.GetEntries() < 1:
    print 'TChain not found or empty...'
    sys.exit(1)
    
print 'Found',ch.GetEntries(),'entries...'

#for entry in xrange(ch.GetEntries()):
entry = 0;
#for entry in xrange(1,2):
print 'Reading entry',entry

ch.GetEntry(entry)

br = None
exec('br = ch.opdigit_%s_branch' % producer)

for opdigit_index in xrange(br.size()):

    print '  Reading OpDigit index',opdigit_index

    opdigit = br[opdigit_index]
    opch = opdigit.ChannelNumber()
 
    if opch > 32: continue

    if not opdigit.size(): continue

    pmt_id = larutil.Geometry.GetME().OpDetFromOpChannel(opch)

    print
    print '    PMT:',pmt_id,'Ch.:',opdigit.ChannelNumber(),'Size:',opdigit.size(),'Time:',opdigit.TimeStamp()
    print

    #pulses  = my_module.Reconstruct (opdigit)
    #pulses2 = my_module2.Reconstruct(opdigit)
    
    ped_mean_and_sigma  = my_module.ReconstructBaseline(opdigit,5)
    
    mean  = ped_mean_and_sigma.first
    sigma = ped_mean_and_sigma.second
    
    plt.hist(np.array(mean))
    plt.yscale('log')
    plt.show()
    plt.hist(np.array(sigma))
    plt.yscale('log')
    plt.show()
    
    #print '    Found',pulses.size(),'pulses!'

    fig,ax = plt.subplots(figsize=(10,6))

    # Create np.array instead of using opdigit as is (which is totally fine) to get useful np.array functions
    # wf = np.array(opdigit)
    wf = np.array(opdigit.Waveform())
        
    plt.plot(np.arange(0,opdigit.size(),1),wf,marker='o',linestyle='--')

    plt.grid()
    plt.xlabel('Time Tick [15.6 ns]',fontsize=20)
    plt.ylabel('ADC',fontsize=20)
    #plt.ylim(ymin-5,ymax+5)
    #plt.xlim(xmin,xmax)
    ax.xaxis.set_tick_params(labelsize=18)
    ax.yaxis.set_tick_params(labelsize=18)
        
    legend = ax.legend(fontsize=32,numpoints=1)
    #legend.get_frame().set_facecolor('#FFFFFF')
    plt.tight_layout()
    #plt.savefig('neutrino_bump_50.eps',format='eps',dpi=20000)
    plt.show()
# Out:
# Found 10 entries...
# Reading entry 0
#   Reading OpDigit index 0
#
#     PMT: 0 Ch.: 29 Size: 1500 Time: 3646.0
#   Reading OpDigit index 1
#
#     PMT: 1 Ch.: 27 Size: 1500 Time: 3646.0
#   Reading OpDigit index 2
#
#     PMT: 2 Ch.: 31 Size: 1500 Time: 3646.0
#   Reading OpDigit index 3
#
#     PMT: 3 Ch.: 26 Size: 1500 Time: 3646.0
#   Reading OpDigit index 4
#
#     PMT: 4 Ch.: 30 Size: 1500 Time: 3646.0
#   Reading OpDigit index 5
#
#     PMT: 5 Ch.: 25 Size: 1500 Time: 3646.0
#   Reading OpDigit index 6
#
#     PMT: 6 Ch.: 28 Size: 1500 Time: 3646.0
#   Reading OpDigit index 7
#
#     PMT: 7 Ch.: 22 Size: 1500 Time: 3646.0
#   Reading OpDigit index 8
#
#     PMT: 8 Ch.: 24 Size: 1500 Time: 3646.0
#   Reading OpDigit index 9
#
#     PMT: 9 Ch.: 20 Size: 1500 Time: 3646.0
#   Reading OpDigit index 10
#
#     PMT: 10 Ch.: 23 Size: 1500 Time: 3646.0
#   Reading OpDigit index 11
#
#     PMT: 11 Ch.: 19 Size: 1500 Time: 3646.0
#   Reading OpDigit index 12
#
#     PMT: 12 Ch.: 21 Size: 1500 Time: 3646.0
#   Reading OpDigit index 13
#
#     PMT: 13 Ch.: 16 Size: 1500 Time: 3646.0
#   Reading OpDigit index 14
#
#     PMT: 14 Ch.: 14 Size: 1500 Time: 3646.0
#   Reading OpDigit index 15
#
#     PMT: 15 Ch.: 18 Size: 1500 Time: 3646.0
#   Reading OpDigit index 16
#
#     PMT: 16 Ch.: 17 Size: 1500 Time: 3646.0
#   Reading OpDigit index 17
#
#     PMT: 17 Ch.: 13 Size: 1500 Time: 3646.0
#   Reading OpDigit index 18
#
#     PMT: 18 Ch.: 15 Size: 1500 Time: 3646.0
#   Reading OpDigit index 19
#
#     PMT: 19 Ch.: 10 Size: 1500 Time: 3646.0
#   Reading OpDigit index 20
#
#     PMT: 20 Ch.: 12 Size: 1500 Time: 3646.0
#   Reading OpDigit index 21
#
#     PMT: 21 Ch.: 8 Size: 1500 Time: 3646.0
#   Reading OpDigit index 22
#
#     PMT: 22 Ch.: 7 Size: 1500 Time: 3646.0
#   Reading OpDigit index 23
#
#     PMT: 23 Ch.: 11 Size: 1500 Time: 3646.0
#   Reading OpDigit index 24
#
#     PMT: 24 Ch.: 9 Size: 1500 Time: 3646.0
#   Reading OpDigit index 25
#
#     PMT: 25 Ch.: 3 Size: 1500 Time: 3646.0
#   Reading OpDigit index 26
#
#     PMT: 26 Ch.: 1 Size: 1500 Time: 3646.0
#   Reading OpDigit index 27
#
#     PMT: 27 Ch.: 6 Size: 1500 Time: 3646.0
#   Reading OpDigit index 28
#
#     PMT: 28 Ch.: 5 Size: 1500 Time: 3646.0
#   Reading OpDigit index 29
#
#     PMT: 29 Ch.: 0 Size: 1500 Time: 3646.0
#   Reading OpDigit index 30
#
#     PMT: 30 Ch.: 2 Size: 1500 Time: 3646.0
#   Reading OpDigit index 31
#
#     PMT: 31 Ch.: 4 Size: 1500 Time: 3646.0
#   Reading OpDigit index 32
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 1808.734375
#   Reading OpDigit index 33
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 1849.0
#   Reading OpDigit index 34
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 1869.6875
#   Reading OpDigit index 35
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 1897.75
#   Reading OpDigit index 36
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 1992.28125
#   Reading OpDigit index 37
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 2020.0625
#   Reading OpDigit index 38
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 2134.625
#   Reading OpDigit index 39
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 2342.3125
#   Reading OpDigit index 40
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 2510.78125
#   Reading OpDigit index 41
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 2562.484375
#   Reading OpDigit index 42
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 2763.796875
#   Reading OpDigit index 43
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 2821.234375
#   Reading OpDigit index 44
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 3043.375
#   Reading OpDigit index 45
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 3103.8125
#   Reading OpDigit index 46
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 3191.078125
#   Reading OpDigit index 47
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 3215.359375
#   Reading OpDigit index 48
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 3239.53125
#   Reading OpDigit index 49
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 3270.578125
#   Reading OpDigit index 50
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 3325.875
#   Reading OpDigit index 51
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 3456.25
#   Reading OpDigit index 52
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 3503.15625
#   Reading OpDigit index 53
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 3588.0
#   Reading OpDigit index 54
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 3711.546875
#   Reading OpDigit index 55
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 4077.625
#   Reading OpDigit index 56
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 4147.984375
#   Reading OpDigit index 57
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 4215.25
#   Reading OpDigit index 58
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 4259.59375
#   Reading OpDigit index 59
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 4396.4375
#   Reading OpDigit index 60
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 4475.28125
#   Reading OpDigit index 61
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 4568.84375
#   Reading OpDigit index 62
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 4642.65625
#   Reading OpDigit index 63
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 4735.671875
#   Reading OpDigit index 64
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 4741.03125
#   Reading OpDigit index 65
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 4763.53125
#   Reading OpDigit index 66
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 4863.609375
#   Reading OpDigit index 67
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 5148.15625
#   Reading OpDigit index 68
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 5706.375
#   Reading OpDigit index 69
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 5749.125
#   Reading OpDigit index 70
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 6039.765625
#   Reading OpDigit index 71
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 6062.0625
#   Reading OpDigit index 72
#
#     PMT: 0 Ch.: 29 Size: 20 Time: 6127.828125
#   Reading OpDigit index 73
#
#     PMT: 1 Ch.: 27 Size: 20 Time: 1790.359375
#   Reading OpDigit index 74
#
#     PMT: 1 Ch.: 27 Size: 20 Time: 1806.1875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-169f7a5c598b> in <module>()
#      69     plt.tight_layout()
#      70     #plt.savefig('neutrino_bump_50.eps',format='eps',dpi=20000)
# ---> 71     plt.show()
#      72
#
# /Library/Python/2.7/site-packages/matplotlib/pyplot.pyc in show(*args, **kw)
#     153     """
#     154     global _show
# --> 155     return _show(*args, **kw)
#     156
#     157
#
# /Library/Python/2.7/site-packages/ipykernel/pylab/backend_inline.pyc in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# /Library/Python/2.7/site-packages/IPython/core/display.pyc in display(*objs, **kwargs)
#     157             publish_display_data(data=obj, metadata=metadata)
#     158         else:
# --> 159             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     160             if not format_dict:
#     161                 # nothing to display (e.g. _ipython_display_ took over)
#
# /Library/Python/2.7/site-packages/IPython/core/formatters.pyc in format(self, obj, include, exclude)
#     173             md = None
#     174             try:
# --> 175                 data = formatter(obj)
#     176             except:
#     177                 # FIXME: log the exception
#
# /Library/Python/2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#
# /Library/Python/2.7/site-packages/IPython/core/formatters.pyc in catch_format_error(method, self, *args, **kwargs)
#     218     """show traceback on failed format call"""
#     219     try:
# --> 220         r = method(self, *args, **kwargs)
#     221     except NotImplementedError:
#     222         # don't warn on NotImplementedErrors
#
# /Library/Python/2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     335                 pass
#     336             else:
# --> 337                 return printer(obj)
#     338             # Finally look for special method names
#     339             method = _safe_get_formatter_method(obj, self.print_method)
#
# /Library/Python/2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     205
#     206     if 'png' in formats:
# --> 207         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     208     if 'retina' in formats or 'png2x' in formats:
#     209         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /Library/Python/2.7/site-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     115
#     116     bytes_io = BytesIO()
# --> 117     fig.canvas.print_figure(bytes_io, **kw)
#     118     data = bytes_io.getvalue()
#     119     if fmt == 'svg':
#
# /Library/Python/2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2156                     orientation=orientation,
#    2157                     dryrun=True,
# -> 2158                     **kwargs)
#    2159                 renderer = self.figure._cachedRenderer
#    2160                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /Library/Python/2.7/site-packages/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     531             _png.write_png(renderer._renderer.buffer_rgba(),
#     532                            renderer.width, renderer.height,
# --> 533                            filename_or_obj, self.figure.dpi)
#     534         finally:
#     535             if close:
#
# KeyboardInterrupt:

# %%
if ch.GetEntries() < 1:
    print 'TChain not found or empty...'
    sys.exit(1)
    
print 'Found',ch.GetEntries(),'entries...'

#for entry in xrange(ch.GetEntries()):

for entry in xrange(1,2):
    print 'Reading entry',entry

    ch.GetEntry(entry)

    br = None
    exec('br = ch.opdigit_%s_branch' % producer)

    for opdigit_index in xrange(br.size()):

        print '  Reading OpDigit index',opdigit_index

        opdigit = br[opdigit_index]
        opch = opdigit.ChannelNumber()
        if opch > 32: continue

        if not opdigit.size(): continue

        pmt_id = larutil.Geometry.GetME().OpDetFromOpChannel(opch)

        print
        print '    PMT:',pmt_id,'Ch.:',opdigit.ChannelNumber(),'Size:',opdigit.size(),'Time:',opdigit.TimeStamp()
        print

        pulses  = my_module.Reconstruct (opdigit)
        pulses2 = my_module2.Reconstruct(opdigit)
        
        print '    Found',pulses.size(),'pulses!'

        fig,ax = plt.subplots(figsize=(10,6))

        # Create np.array instead of using opdigit as is (which is totally fine) to get useful np.array functions
        # wf = np.array(opdigit)
        wf = np.array(opdigit.Waveform())
        
        plt.plot(np.arange(0,opdigit.size(),1),wf,marker='o',linestyle='--')

        ymax = wf.max()
        ymin = wf.min()

        xmin = 0
        xmax = len(opdigit)
        a = 0
        b = 0
        
        for p in pulses2:

            # span_xmin = p.t_start / len(opdigit)
            # span_xmax = p.t_end / len(opdigit)

            # span_ymax = p.peak + p.ped_mean
            # span_ymin = p.ped_mean

            span_xmin = p.t_start
            span_xmax = p.t_end

            span_ymax = p.peak + p.ped_mean
            span_ymin = p.ped_mean
            
            
            ax.add_patch(patches.Rectangle((span_xmin, span_ymin),
                                           span_xmax - span_xmin,
                                           span_ymax - span_ymin,
                                           color='green',alpha=0.5,lw=2))
        for p in pulses:

            # span_xmin = p.t_start / len(opdigit)
            # span_xmax = p.t_end / len(opdigit)

            # span_ymax = p.peak + p.ped_mean
            # span_ymin = p.ped_mean

            span_xmin = p.t_start
            span_xmax = p.t_end

            span_ymax = p.peak + p.ped_mean
            span_ymin = p.ped_mean
            
            
            ax.add_patch(patches.Rectangle((span_xmin, span_ymin),
                                           span_xmax - span_xmin,
                                           span_ymax - span_ymin,
                                           color='orange',alpha=0.5,lw=2))

            # plt.axhspan(xmin = span_xmin,
            #             xmax = span_xmax,
            #             ymin = span_ymin,
            #             ymax = span_ymax,
            #             color='orange',lw=2,alpha=0.5)



            #print span_xmin, span_xmax, span_ymin, span_ymax

            #if xmin == 0: xmin = span_xmin
            #if xmax == len(opdigit): xmax = span_xmax

        plt.grid()
        plt.xlabel('Time Tick [15.6 ns]',fontsize=20)
        plt.ylabel('ADC',fontsize=20)
        plt.ylim(ymin-5,ymax+5)
        #plt.xlim(a-2,b+2)
        #plt.xlim(0,len(wf))
        plt.xlim(xmin,xmax)
        ax.xaxis.set_tick_params(labelsize=18)
        ax.yaxis.set_tick_params(labelsize=18)
        
        #ax.xaxis.labelpad=12
        #ax.yaxis.labelpad=12
        legend = ax.legend(fontsize=32,numpoints=1)
        #legend.get_frame().set_facecolor('#FFFFFF')
        plt.tight_layout()
        #plt.savefig('neutrino_bump_50.eps',format='eps',dpi=20000)
        plt.show()
